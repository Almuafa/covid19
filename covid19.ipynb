# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
from covid import pull_state_data_by_date, pull_state_data_by_county, pull_states

# %% [markdown]
# ### Get the states names and write them to a list file.

# %%
states = pull_states()
with open('data\states.lst', 'w') as file_handler:
    for state in states:
        file_handler.write(f'{state},\n')

# %% [markdown]
# ### Get cases for state by date

# %%
# unit testing
dataframe = pull_state_data_by_date('Alabama')
dataframe.head()
# Out:
#         date confirmed deaths    state
# 0 2020-03-11         3      0  Alabama
# 1 2020-03-12         4      0  Alabama
# 2 2020-03-13         8      0  Alabama
# 3 2020-03-14        14      0  Alabama
# 4 2020-03-15        26      0  Alabama

# %%
states = open('data\states.lst', 'r').read().split(',')

for state in states:
    state = state.lstrip()
    print(f'pulling data for state: {state}')
    try:
        df = pull_state_data_by_date(state)
    except:
        print(f'skipping {state}, since its erroring...')
    
    print(f'writing to csv, for state: {state}')
    df.to_csv(f'data\{state}.csv', index=False)
    print(f'file written to: {state}.csv')
    print('')
# Out:
# pulling data for state: Alabama
# writing to csv, for state: Alabama
# file written to: Alabama.csv
#
# pulling data for state: Alaska
# writing to csv, for state: Alaska
# file written to: Alaska.csv
#
# pulling data for state: American_Samoa
# writing to csv, for state: American_Samoa
# file written to: American_Samoa.csv
#
# pulling data for state: Arizona
# writing to csv, for state: Arizona
# file written to: Arizona.csv
#
# pulling data for state: Arkansas
# writing to csv, for state: Arkansas
# file written to: Arkansas.csv
#
# pulling data for state: California
# writing to csv, for state: California
# file written to: California.csv
#
# pulling data for state: Colorado
# writing to csv, for state: Colorado
# file written to: Colorado.csv
#
# pulling data for state: Connecticut
# writing to csv, for state: Connecticut
# file written to: Connecticut.csv
#
# pulling data for state: Delaware
# writing to csv, for state: Delaware
# file written to: Delaware.csv
#
# pulling data for state: District_of_Columbia
# writing to csv, for state: District_of_Columbia
# file written to: District_of_Columbia.csv
#
# pulling data for state: Florida
# writing to csv, for state: Florida
# file written to: Florida.csv
#
# pulling data for state: Georgia
# writing to csv, for state: Georgia
# file written to: Georgia.csv
#
# pulling data for state: Guam
# writing to csv, for state: Guam
# file written to: Guam.csv
#
# pulling data for state: Hawaii
# writing to csv, for state: Hawaii
# file written to: Hawaii.csv
#
# pulling data for state: Idaho
# writing to csv, for state: Idaho
# file written to: Idaho.csv
#
# pulling data for state: Illinois
# writing to csv, for state: Illinois
# file written to: Illinois.csv
#
# pulling data for state: Indiana
# writing to csv, for state: Indiana
# file written to: Indiana.csv
#
# pulling data for state: Iowa
# writing to csv, for state: Iowa
# file written to: Iowa.csv
#
# pulling data for state: Kansas
# writing to csv, for state: Kansas
# file written to: Kansas.csv
#
# pulling data for state: Kentucky
# writing to csv, for state: Kentucky
# file written to: Kentucky.csv
#
# pulling data for state: Louisiana
# writing to csv, for state: Louisiana
# file written to: Louisiana.csv
#
# pulling data for state: Maine
# writing to csv, for state: Maine
# file written to: Maine.csv
#
# pulling data for state: Maryland
# writing to csv, for state: Maryland
# file written to: Maryland.csv
#
# pulling data for state: Massachusetts
# writing to csv, for state: Massachusetts
# file written to: Massachusetts.csv
#
# pulling data for state: Michigan
# writing to csv, for state: Michigan
# file written to: Michigan.csv
#
# pulling data for state: Minnesota
# writing to csv, for state: Minnesota
# file written to: Minnesota.csv
#
# pulling data for state: Mississippi
# writing to csv, for state: Mississippi
# file written to: Mississippi.csv
#
# pulling data for state: Missouri
# writing to csv, for state: Missouri
# file written to: Missouri.csv
#
# pulling data for state: Montana
# writing to csv, for state: Montana
# file written to: Montana.csv
#
# pulling data for state: Nebraska
# writing to csv, for state: Nebraska
# file written to: Nebraska.csv
#
# pulling data for state: Nevada
# writing to csv, for state: Nevada
# file written to: Nevada.csv
#
# pulling data for state: New_Hampshire
# writing to csv, for state: New_Hampshire
# file written to: New_Hampshire.csv
#
# pulling data for state: New_Jersey
# writing to csv, for state: New_Jersey
# file written to: New_Jersey.csv
#
# pulling data for state: New_Mexico
# writing to csv, for state: New_Mexico
# file written to: New_Mexico.csv
#
# pulling data for state: New_York
# writing to csv, for state: New_York
# file written to: New_York.csv
#
# pulling data for state: North_Carolina
# writing to csv, for state: North_Carolina
# file written to: North_Carolina.csv
#
# pulling data for state: North_Dakota
# writing to csv, for state: North_Dakota
# file written to: North_Dakota.csv
#
# pulling data for state: Northern_Mariana_Islands
# writing to csv, for state: Northern_Mariana_Islands
# file written to: Northern_Mariana_Islands.csv
#
# pulling data for state: Ohio
# writing to csv, for state: Ohio
# file written to: Ohio.csv
#
# pulling data for state: Oklahoma
# writing to csv, for state: Oklahoma
# file written to: Oklahoma.csv
#
# pulling data for state: Oregon
# writing to csv, for state: Oregon
# file written to: Oregon.csv
#
# pulling data for state: Pennsylvania
# writing to csv, for state: Pennsylvania
# file written to: Pennsylvania.csv
#
# pulling data for state: Puerto_Rico
# writing to csv, for state: Puerto_Rico
# file written to: Puerto_Rico.csv
#
# pulling data for state: Rhode_Island
# writing to csv, for state: Rhode_Island
# file written to: Rhode_Island.csv
#
# pulling data for state: South_Carolina
# writing to csv, for state: South_Carolina
# file written to: South_Carolina.csv
#
# pulling data for state: South_Dakota
# writing to csv, for state: South_Dakota
# file written to: South_Dakota.csv
#
# pulling data for state: Tennessee
# writing to csv, for state: Tennessee
# file written to: Tennessee.csv
#
# pulling data for state: Texas
# writing to csv, for state: Texas
# file written to: Texas.csv
#
# pulling data for state: US_Virgin_Islands
# writing to csv, for state: US_Virgin_Islands
# file written to: US_Virgin_Islands.csv
#
# pulling data for state: Utah
# writing to csv, for state: Utah
# file written to: Utah.csv
#
# pulling data for state: Vermont
# writing to csv, for state: Vermont
# file written to: Vermont.csv
#
# pulling data for state: Virginia
# writing to csv, for state: Virginia
# file written to: Virginia.csv
#
# pulling data for state: Washington
# writing to csv, for state: Washington
# file written to: Washington.csv
#
# pulling data for state: West_Virginia
# writing to csv, for state: West_Virginia
# file written to: West_Virginia.csv
#
# pulling data for state: Wisconsin
# writing to csv, for state: Wisconsin
# file written to: Wisconsin.csv
#
# pulling data for state:
# writing to csv, for state:
# file written to: .csv

# %% [markdown]
# ### Get cases for state by county

# %%
# unit testing
dataframe = pull_state_data_by_county('Alabama')
dataframe.head()
# Out:
#   County[a] Cases [b][c] Deaths [c] Population[3] Cases / 100k    CFR
# 0   67 / 67       104079       1830       4779736       2117.5  1.76%
# 1   Autauga         1218         22         54571       2232.0  1.81%
# 2   Baldwin         3877         29        182265       2127.1  0.75%
# 3   Barbour          604          6         27457       2119.8  0.99%
# 4      Bibb          469          5         22915       2046.7  1.07%

# %%
states = open('data\states.lst', 'r').read().split(',')

for state in states:
    state = state.lstrip()
    print(f'pulling data for state: {state}')
    try:
        df = pull_state_data_by_county(state)
    except:
        print(f'{state} is skipped, due to errors')
    
    print(f'writing to csv, for state: {state}')
    df.to_csv(f'data\{state}county.csv', index=False)
    print(f'file written to: {state}.csv')
    print('')
# Out:
# pulling data for state: Alabama
# writing to csv, for state: Alabama
# file written to: Alabama.csv
#
# pulling data for state: Alaska
# writing to csv, for state: Alaska
# file written to: Alaska.csv
#
# pulling data for state: American_Samoa
# writing to csv, for state: American_Samoa
# file written to: American_Samoa.csv
#
# pulling data for state: Arizona
# writing to csv, for state: Arizona
# file written to: Arizona.csv
#
# pulling data for state: Arkansas
# writing to csv, for state: Arkansas
# file written to: Arkansas.csv
#
# pulling data for state: California
# writing to csv, for state: California
# file written to: California.csv
#
# pulling data for state: Colorado
# writing to csv, for state: Colorado
# file written to: Colorado.csv
#
# pulling data for state: Connecticut
# writing to csv, for state: Connecticut
# file written to: Connecticut.csv
#
# pulling data for state: Delaware
# writing to csv, for state: Delaware
# file written to: Delaware.csv
#
# pulling data for state: District_of_Columbia
# writing to csv, for state: District_of_Columbia
# file written to: District_of_Columbia.csv
#
# pulling data for state: Florida
# writing to csv, for state: Florida
# file written to: Florida.csv
#
# pulling data for state: Georgia
# Georgia is skipped, due to errors
# writing to csv, for state: Georgia
# file written to: Georgia.csv
#
# pulling data for state: Guam
# Guam is skipped, due to errors
# writing to csv, for state: Guam
# file written to: Guam.csv
#
# pulling data for state: Hawaii
# writing to csv, for state: Hawaii
# file written to: Hawaii.csv
#
# pulling data for state: Idaho
# writing to csv, for state: Idaho
# file written to: Idaho.csv
#
# pulling data for state: Illinois
# Illinois is skipped, due to errors
# writing to csv, for state: Illinois
# file written to: Illinois.csv
#
# pulling data for state: Indiana
# writing to csv, for state: Indiana
# file written to: Indiana.csv
#
# pulling data for state: Iowa
# writing to csv, for state: Iowa
# file written to: Iowa.csv
#
# pulling data for state: Kansas
# writing to csv, for state: Kansas
# file written to: Kansas.csv
#
# pulling data for state: Kentucky
# writing to csv, for state: Kentucky
# file written to: Kentucky.csv
#
# pulling data for state: Louisiana
# writing to csv, for state: Louisiana
# file written to: Louisiana.csv
#
# pulling data for state: Maine
# writing to csv, for state: Maine
# file written to: Maine.csv
#
# pulling data for state: Maryland
# writing to csv, for state: Maryland
# file written to: Maryland.csv
#
# pulling data for state: Massachusetts
# writing to csv, for state: Massachusetts
# file written to: Massachusetts.csv
#
# pulling data for state: Michigan
# Michigan is skipped, due to errors
# writing to csv, for state: Michigan
# file written to: Michigan.csv
#
# pulling data for state: Minnesota
# writing to csv, for state: Minnesota
# file written to: Minnesota.csv
#
# pulling data for state: Mississippi
# writing to csv, for state: Mississippi
# file written to: Mississippi.csv
#
# pulling data for state: Missouri
# writing to csv, for state: Missouri
# file written to: Missouri.csv
#
# pulling data for state: Montana
# writing to csv, for state: Montana
# file written to: Montana.csv
#
# pulling data for state: Nebraska
# writing to csv, for state: Nebraska
# file written to: Nebraska.csv
#
# pulling data for state: Nevada
# writing to csv, for state: Nevada
# file written to: Nevada.csv
#
# pulling data for state: New_Hampshire
# writing to csv, for state: New_Hampshire
# file written to: New_Hampshire.csv
#
# pulling data for state: New_Jersey
# writing to csv, for state: New_Jersey
# file written to: New_Jersey.csv
#
# pulling data for state: New_Mexico
# writing to csv, for state: New_Mexico
# file written to: New_Mexico.csv
#
# pulling data for state: New_York
# New_York is skipped, due to errors
# writing to csv, for state: New_York
# file written to: New_York.csv
#
# pulling data for state: North_Carolina
# writing to csv, for state: North_Carolina
# file written to: North_Carolina.csv
#
# pulling data for state: North_Dakota
# writing to csv, for state: North_Dakota
# file written to: North_Dakota.csv
#
# pulling data for state: Northern_Mariana_Islands
# Northern_Mariana_Islands is skipped, due to errors
# writing to csv, for state: Northern_Mariana_Islands
# file written to: Northern_Mariana_Islands.csv
#
# pulling data for state: Ohio
# writing to csv, for state: Ohio
# file written to: Ohio.csv
#
# pulling data for state: Oklahoma
# writing to csv, for state: Oklahoma
# file written to: Oklahoma.csv
#
# pulling data for state: Oregon
# writing to csv, for state: Oregon
# file written to: Oregon.csv
#
# pulling data for state: Pennsylvania
# writing to csv, for state: Pennsylvania
# file written to: Pennsylvania.csv
#
# pulling data for state: Puerto_Rico
# writing to csv, for state: Puerto_Rico
# file written to: Puerto_Rico.csv
#
# pulling data for state: Rhode_Island
# writing to csv, for state: Rhode_Island
# file written to: Rhode_Island.csv
#
# pulling data for state: South_Carolina
# writing to csv, for state: South_Carolina
# file written to: South_Carolina.csv
#
# pulling data for state: South_Dakota
# writing to csv, for state: South_Dakota
# file written to: South_Dakota.csv
#
# pulling data for state: Tennessee
# Tennessee is skipped, due to errors
# writing to csv, for state: Tennessee
# file written to: Tennessee.csv
#
# pulling data for state: Texas
# writing to csv, for state: Texas
# file written to: Texas.csv
#
# pulling data for state: US_Virgin_Islands
# US_Virgin_Islands is skipped, due to errors
# writing to csv, for state: US_Virgin_Islands
# file written to: US_Virgin_Islands.csv
#
# pulling data for state: Utah
# writing to csv, for state: Utah
# file written to: Utah.csv
#
# pulling data for state: Vermont
# writing to csv, for state: Vermont
# file written to: Vermont.csv
#
# pulling data for state: Virginia
# writing to csv, for state: Virginia
# file written to: Virginia.csv
#
# pulling data for state: Washington
# Washington is skipped, due to errors
# writing to csv, for state: Washington
# file written to: Washington.csv
#
# pulling data for state: West_Virginia
# writing to csv, for state: West_Virginia
# file written to: West_Virginia.csv
#
# pulling data for state: Wisconsin
# writing to csv, for state: Wisconsin
# file written to: Wisconsin.csv
#
# pulling data for state:
#  is skipped, due to errors
# writing to csv, for state:
# file written to: .csv
